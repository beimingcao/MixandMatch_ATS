# %%
import os
import glob
import re
from pandas import DataFrame
import matplotlib.pyplot as plt

# %%
def atoi(text):
    
    return int(text) if text.isdigit() else text

def natural_keys(text):

    return [ atoi(c) for c in re.split(r'(\d+)', text) ]

# %%
EMA_data_path = '/home/beiming/Projects/SI_ATS/Database/RAW_DATA/EMA_MAE'
group_name = 'ENF'
speaker_id  = '05ENF'

# %%
group_path = os.path.join(EMA_data_path, group_name)
speaker_path = os.path.join(group_path, speaker_id)
speaker_data_path = os.path.join(speaker_path, 'EMA Data')

# %%
EMA_path = os.path.join(speaker_data_path, '*' + '.tsv')
EMA_path_list = glob.glob(EMA_path)
EMA_path_list.sort()

# %% [markdown]
# ### Pick one file as sample

# %%
sample_path = EMA_path_list[0]

# %%
df = DataFrame.from_csv(sample_path, sep="\t")
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   """Entry point for launching an IPython kernel.

# %%
I = df.values
print(I[0,:])
# Out:
# [ 5.000000e+00  3.300000e+01  0.000000e+00  5.500000e+01  4.191910e+01
#   4.802300e+01 -1.494785e+02  9.994000e-01  1.160000e-02 -2.780000e-02
#  -1.850000e-02  1.000000e+00  5.500000e+01 -3.669360e+01  2.109780e+01
#  -4.963400e+00 -3.754000e-01 -9.214000e-01  3.630000e-02 -9.330000e-02
#   2.000000e+00  5.500000e+01 -2.572100e+01  1.417540e+01 -1.405670e+01
#  -4.282000e-01 -8.356000e-01  3.274000e-01 -1.058000e-01  3.000000e+00
#   5.500000e+01 -1.960810e+01  1.776200e+01 -2.850000e-02 -9.116000e-01
#  -3.734000e-01  8.540000e-02 -1.493000e-01  4.000000e+00  5.500000e+01
#   8.519600e+00  1.797540e+01  1.631700e+00 -5.881000e-01 -7.891000e-01
#   1.297000e-01 -1.211000e-01  5.000000e+00  5.500000e+01  8.056800e+00
#  -4.362800e+00  1.654300e+00 -5.459000e-01 -2.795000e-01 -7.870000e-01
#  -6.740000e-02  6.000000e+00  5.500000e+01  1.391000e-01  4.578500e+00
#  -2.274160e+01 -6.336000e-01 -7.565000e-01 -1.099000e-01 -1.194000e-01
# ...

# %%
Sensor1 = I[:,4:7] # Ref
Sensor2 = I[:,13:16] # TD
Sensor3 = I[:,22:25] # TL
Sensor4 = I[:,31:34] # TB
Sensor5 = I[:,40:43] # UL
Sensor6 = I[:,49:52] # LL
Sensor7 = I[:,58:61] # LC
Sensor8 = I[:,67:70] # MI
Sensor9 = I[:,76:79] # Palate Probe
Sensor10 = I[:,85:88] # Biteplate OS
Sensor11 = I[:,94:97] # Biteplate MS

# %%
plt.plot(
        Sensor2[:,1], Sensor2[:,0], 'g', Sensor3[:,1], Sensor3[:,0], 'b', Sensor4[:,1], Sensor4[:,0], 'k',
        Sensor5[:,1], Sensor5[:,0], 'm', Sensor6[:,1], Sensor6[:,0], 'c', Sensor7[:,1], Sensor7[:,0], 'r',
        Sensor8[:,1], Sensor8[:,0], 'y')

# %%
Sensor1 = I[:,4:7] # Ref
Sensor2 = I[:,13:16] # TD
Sensor3 = I[:,22:25] # TL
Sensor4 = I[:,31:34] # TB
Sensor5 = I[:,40:43] # UL
Sensor6 = I[:,49:52] # LL
Sensor7 = I[:,58:61] # LC
Sensor8 = I[:,67:70] # MI
Sensor9 = I[:,76:79] # Palate Probe
Sensor10 = I[:,85:88] # Biteplate OS
Sensor11 = I[:,94:97] # Biteplate MS

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(Sensor2[:,1], Sensor2[:,0], Sensor2[:,2], 'g')
ax.plot3D(Sensor3[:,1], Sensor3[:,0], Sensor3[:,2], 'b')
ax.plot3D(Sensor4[:,1], Sensor4[:,0], Sensor4[:,2], 'k')
ax.plot3D(Sensor5[:,1], Sensor5[:,0], Sensor5[:,2], 'c')
ax.plot3D(Sensor6[:,1], Sensor6[:,0], Sensor6[:,2], 'm')
ax.plot3D(Sensor7[:,1], Sensor7[:,0], Sensor7[:,2], 'y')
ax.plot3D(Sensor8[:,1], Sensor8[:,0], Sensor8[:,2], 'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
I = I[0:1000, :]

# %%
Sensor1 = I[:,5:8] # Ref
Sensor2 = I[:,14:17] # TD
Sensor3 = I[:,23:26] # TL
Sensor4 = I[:,32:35] # TB
Sensor5 = I[:,41:44] # UL
Sensor6 = I[:,50:53] # LL
Sensor7 = I[:,59:62] # LC
Sensor8 = I[:,68:71] # MI
Sensor9 = I[:,77:80] # Palate Probe
Sensor10 = I[:,86:89] # Biteplate OS
Sensor11 = I[:,95:98] # Biteplate MS

# %%
from mpl_toolkits import mplot3d
import matplotlib.pyplot as plt

# %matplotlib notebook

fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot3D(Sensor2[:,1], Sensor2[:,0], Sensor2[:,2], 'g')
ax.plot3D(Sensor3[:,1], Sensor3[:,0], Sensor3[:,2], 'b')
ax.plot3D(Sensor4[:,1], Sensor4[:,0], Sensor4[:,2], 'k')
ax.plot3D(Sensor5[:,1], Sensor5[:,0], Sensor5[:,2], 'c')
ax.plot3D(Sensor6[:,1], Sensor6[:,0], Sensor6[:,2], 'm')
ax.plot3D(Sensor7[:,1], Sensor7[:,0], Sensor7[:,2], 'y')
ax.plot3D(Sensor8[:,1], Sensor8[:,0], Sensor8[:,2], 'r')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">
